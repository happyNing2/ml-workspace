# %% [markdown]
# ### 시계열 데이터
# * 시계열 데이터
#     - 시간의 흐름에 따라 데이터의 변화를 분석 및 예측하는데 사용되는 데이터
#     - 타임스탬프(timestamp) : 특정 시점(시간)을 의미하는 자료형
# * 기능
#     - to_datetime : 데이터를 시간 자료형으로 변환시켜주는 함수
#     - to_period : 날짜 데이터의 년, 월, 일 등을 가져올 수 있다.
#         * 옵션
#             - freq를 이용하여 각각의 날짜 정보를 얻어올 수 있다
#             - freq = A(년), M(월), D(일)
#             - D지정시 2020-01-01까지 나오며, M지정시 2020-01, A지정시 2020까지 나온다.
#     - Datetimeindex자료형
#         * dt객체를 제공하며, dt.year, dt.month, dt.day, dt.hour, dt.minute, dt.second...등을 제공한다
# >
# * 자세한 정보는 다음 사이트를 참조하기 바란다.
# * https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DatetimeIndex.html

# %%
import pandas as pd
dates = ['2026-03-04', '2026-05-05']
df = pd.DataFrame(dates, columns=['date'])
df
# Out:
#          date
# 0  2026-03-04
# 1  2026-05-05

# %%
df.dtypes
# Out:
# date    str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    2 non-null      str
# dtypes: str(1)
# memory usage: 148.0 bytes

# %%
df['new_date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      2 non-null      str
#  1   new_date  2 non-null      datetime64[us]
# dtypes: datetime64[us](1), str(1)
# memory usage: 164.0 bytes

# %%
df
# Out:
#          date   new_date
# 0  2026-03-04 2026-03-04
# 1  2026-05-05 2026-05-05

# %%
print( df['new_date'].dt.year )
df['year'] = df['new_date'].dt.year
df['month'] = df['new_date'].dt.month
df['day'] = df['new_date'].dt.day

df
# Out:
# 0    2026
# 1    2026
# Name: new_date, dtype: int32
#          date   new_date  year  month  day
# 0  2026-03-04 2026-03-04  2026      3    4
# 1  2026-05-05 2026-05-05  2026      5    5

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      2 non-null      str
#  1   new_date  2 non-null      datetime64[us]
#  2   year      2 non-null      int32
#  3   month     2 non-null      int32
#  4   day       2 non-null      int32
# dtypes: datetime64[us](1), int32(3), str(1)
# memory usage: 188.0 bytes

# %%
datas = [1, 2, 3]
df = pd.DataFrame(datas, columns=['data'])
df
# Out:
#    data
# 0     1
# 1     2
# 2     3

# %%
def test (num:int) -> int :
    print("test 실행", num)
    return num * 10

# %%
df['data'].apply( test )
# Out:
# test 실행 1
# test 실행 2
# test 실행 3
# 0    10
# 1    20
# 2    30
# Name: data, dtype: int64

# %%
test2 = lambda n : n*100

# %%
# df['data'].apply( test2 )
df['data'].apply( lambda n : n*100 )
# Out:
# 0    100
# 1    200
# 2    300
# Name: data, dtype: int64

# %%
dates = ['2026-03-04', '2026-05-05']
df = pd.DataFrame(dates, columns=['date'])
df
# Out:
#          date
# 0  2026-03-04
# 1  2026-05-05

# %%
datetimer = df['date'].apply( lambda x : pd.to_datetime(x) )
datetimer.info(), datetimer
# Out:
# <class 'pandas.Series'>
# RangeIndex: 2 entries, 0 to 1
# Series name: date
# Non-Null Count  Dtype
# --------------  -----
# 2 non-null      datetime64[us]
# dtypes: datetime64[us](1)
# memory usage: 148.0 bytes
# (None,
#  0   2026-03-04
#  1   2026-05-05
#  Name: date, dtype: datetime64[us])

# %%
datetimer.dt.year
# Out:
# 0    2026
# 1    2026
# Name: date, dtype: int32

# %%
df['year'] = datetimer.apply( lambda x : x.year )
df['month'] = datetimer.apply( lambda x : x.month )
df['day'] = datetimer.apply( lambda x : x.day )
df['dayofweek'] = datetimer.apply( lambda x : x.dayofweek )
df
# Out:
#          date  year  month  day  dayofweek
# 0  2026-03-04  2026      3    4          2
# 1  2026-05-05  2026      5    5          1

# %%
# df.drop(columns=['day'])

# %%
df['month'] = df['month'].apply( lambda x : 1111 if x > 3 else x)
df
# Out:
#          date  year  month  day  dayofweek
# 0  2026-03-04  2026      3    4          2
# 1  2026-05-05  2026   1111    5          1

# %%
mask = (df['year'] == 2026) & (df['month'] == 1111)
df[ (df['year'] == 2026) & (df['month'] == 1111) ]
# Out:
#          date  year  month  day  dayofweek
# 1  2026-05-05  2026   1111    5          1

# %%
print(df[ mask ])
print("-" * 20)
df.loc[mask, 'dayofweek'] = df[mask]['dayofweek'].apply( lambda x : 111 if x == 1 else x )
# Out:
#          date  year  month  day  dayofweek
# 1  2026-05-05  2026   1111    5          1
# --------------------

# %%
df
# Out:
#          date  year  month  day  dayofweek
# 0  2026-03-04  2026      3    4          2
# 1  2026-05-05  2026   1111    5        111

# %%
df_test = df[ ['date', 'year'] ]
df_test
# Out:
#          date  year
# 0  2026-03-04  2026
# 1  2026-05-05  2026

# %%
df_test.to_dict()
# Out:
# {'date': {0: '2026-03-04', 1: '2026-05-05'}, 'year': {0: 2026, 1: 2026}}

# %%
df_test = df_test.to_dict('list')
df_test
# Out:
# {'date': ['2026-03-04', '2026-05-05'], 'year': [2026, 2026]}

# %%
df_date = df_test['date']
print( df_date )
df_year = df_test['year']
print( df_year )
# Out:
# ['2026-03-04', '2026-05-05']
# [2026, 2026]

# %%
for i in range( len(df_year) ) :
    print( df_year[i], ":", df_date[i] )
# Out:
# 2026 : 2026-03-04
# 2026 : 2026-05-05
