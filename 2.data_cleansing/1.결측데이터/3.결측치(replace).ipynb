# %%
import pandas as pd

# %%
df = pd.read_csv("../../data_set/2.데이터 클린징/nan.csv")
df
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0      0      1      2    1.7    NaN
# 1      3      4      2    NaN    NaN
# 2      3      4      8    2.4    NaN
# 3      9     10     11    NaN    NaN
# 4     12     10     14    1.2    NaN
# 5     15     16     17    NaN    1.0

# %%
# to_replace = 비교값, vaue = 변경값
df.replace(to_replace=2, value=200)
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0      0      1    200    1.7    NaN
# 1      3      4    200    NaN    NaN
# 2      3      4      8    2.4    NaN
# 3      9     10     11    NaN    NaN
# 4     12     10     14    1.2    NaN
# 5     15     16     17    NaN    1.0

# %%
df
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0      0      1      2    1.7    NaN
# 1      3      4      2    NaN    NaN
# 2      3      4      8    2.4    NaN
# 3      9     10     11    NaN    NaN
# 4     12     10     14    1.2    NaN
# 5     15     16     17    NaN    1.0

# %%
import numpy as np

df.replace(to_replace=np.nan, value="변경값")
# Out:
#    data1  data2  data3 nan_1 nan_2
# 0      0      1      2   1.7   변경값
# 1      3      4      2   변경값   변경값
# 2      3      4      8   2.4   변경값
# 3      9     10     11   변경값   변경값
# 4     12     10     14   1.2   변경값
# 5     15     16     17   변경값   1.0

# %%
df.replace(to_replace={"nan_2":np.nan}, value="치환", inplace=True)
df
# Out:
#    data1  data2  data3  nan_1 nan_2
# 0      0      1      2    1.7    치환
# 1      3      4      2    NaN    치환
# 2      3      4      8    2.4    치환
# 3      9     10     11    NaN    치환
# 4     12     10     14    1.2    치환
# 5     15     16     17    NaN   1.0

# %%
df = pd.read_csv("../../data_set/2.데이터 클린징/bicycle.csv")
df
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# ..         ...               ...    ...                ...    ...
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
# 420  SPB-23012  2019-11-14 19:53    267          삼성화재 사옥 옆    2.0
# 421  SPB-13934  2019-11-13 18:00    106         합정역 7번출구 앞    4.0
# 422  SPB-09287   2019-11-26 8:36    911    은평평화공원(역촌역4번출구)    4.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리   나이
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0   50
# ...

# %%
df[ df['대여소번호'] == 646 ]
# Out:
#         자전거번호             대여일시  대여소번호               대여소명  대여거치대  \
# 0   SPB-23220  2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1   SPB-16216  2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2   SPB-21097  2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3   SPB-22292  2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 5   SPB-18401  2019-11-06 8:52    646  장한평역 1번출구 (국민은행앞)    1.0
# 6   SPB-18350  2019-11-06 8:35    646  장한평역 1번출구 (국민은행앞)    1.0
# 8   SPB-20220  2019-11-11 8:35    646  장한평역 1번출구 (국민은행앞)    2.0
# 9   SPB-20102  2019-11-11 9:45    646  장한평역 1번출구 (국민은행앞)    8.0
# 10  SPB-10000  2019-11-12 8:35    646  장한평역 1번출구 (국민은행앞)    8.0
# 11  SPB-20145  2019-11-13 8:30    646  장한평역 1번출구 (국민은행앞)    9.0
# 12  SPB-19057  2019-11-13 8:55    646  장한평역 1번출구 (국민은행앞)    4.0
# 13  SPB-19645  2019-11-14 9:44    646  장한평역 1번출구 (국민은행앞)    NaN
# 14  SPB-21851  2019-11-14 9:33    646  장한평역 1번출구 (국민은행앞)   10.0
# 15  SPB-13973  2019-11-15 8:42    646  장한평역 1번출구 (국민은행앞)    1.0
# ...

# %%
df.loc[ df['대여소번호'] == 646 ]
# Out:
#         자전거번호             대여일시  대여소번호               대여소명  대여거치대  \
# 0   SPB-23220  2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1   SPB-16216  2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2   SPB-21097  2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3   SPB-22292  2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 5   SPB-18401  2019-11-06 8:52    646  장한평역 1번출구 (국민은행앞)    1.0
# 6   SPB-18350  2019-11-06 8:35    646  장한평역 1번출구 (국민은행앞)    1.0
# 8   SPB-20220  2019-11-11 8:35    646  장한평역 1번출구 (국민은행앞)    2.0
# 9   SPB-20102  2019-11-11 9:45    646  장한평역 1번출구 (국민은행앞)    8.0
# 10  SPB-10000  2019-11-12 8:35    646  장한평역 1번출구 (국민은행앞)    8.0
# 11  SPB-20145  2019-11-13 8:30    646  장한평역 1번출구 (국민은행앞)    9.0
# 12  SPB-19057  2019-11-13 8:55    646  장한평역 1번출구 (국민은행앞)    4.0
# 13  SPB-19645  2019-11-14 9:44    646  장한평역 1번출구 (국민은행앞)    NaN
# 14  SPB-21851  2019-11-14 9:33    646  장한평역 1번출구 (국민은행앞)   10.0
# 15  SPB-13973  2019-11-15 8:42    646  장한평역 1번출구 (국민은행앞)    1.0
# ...

# %%
df.columns
# Out:
# Index(['자전거번호', '대여일시', '대여소번호', '대여소명', '대여거치대', '반납일시', '반납대여소번호', '반납대여소명',
#        '반납거치대', '이용시간', '이용거리', '나이'],
#       dtype='str')

# %%
df[ df['대여소번호']==646 ][ ['대여거치대', '반납일시'] ]
df.loc[ df['대여소번호']==646, ['대여거치대', '반납일시'] ]
# Out:
#     대여거치대              반납일시
# 0     3.0   2019-11-01 9:01
# 1     2.0   2019-11-04 8:56
# 2     1.0   2019-11-04 8:57
# 3     1.0   2019-11-05 8:45
# 5     1.0   2019-11-06 9:09
# 6     1.0   2019-11-06 9:10
# 8     2.0   2019-11-11 8:42
# 9     8.0  2019-11-11 10:17
# 10    8.0   2019-11-12 8:44
# 11    9.0   2019-11-13 8:38
# 12    4.0   2019-11-13 9:08
# 13    NaN  2019-11-14 10:01
# 14   10.0  2019-11-14 10:02
# 15    1.0   2019-11-15 8:50
# 16    6.0   2019-11-18 8:39
# 17    4.0   2019-11-18 9:01
# 18    NaN   2019-11-21 8:44
# 19    2.0   2019-11-21 9:04
# 21    5.0   2019-11-25 8:49
# 22    6.0   2019-11-26 8:48
# 24    6.0   2019-11-28 8:44

# %%
df[ df['대여소번호']==646 ]['이용거리']
df[ df['대여소번호']==646 ]['이용거리'].isnull()
df[ df['대여소번호']==646 ]['이용거리'].isnull().sum()
# Out:
# np.int64(2)

# %%
df[ df['대여소번호']==646 ]['이용거리'].fillna(789.789)
df.loc[ df['대여소번호'] == 646, '이용거리' ].fillna(123.123)
# Out:
# 0     1100.000
# 1     1420.000
# 2      123.123
# 3     1380.000
# 5     1350.000
# 6     1390.000
# 8     1160.000
# 9     1060.000
# 10    1300.000
# 11    1060.000
# 12     123.123
# 13    1140.000
# 14    1220.000
# 15    1370.000
# 16    1350.000
# 17    1350.000
# 18    1130.000
# 19    1330.000
# 21    1310.000
# 22    1380.000
# 24    1070.000
# Name: 이용거리, dtype: float64

# %%
df[ df['대여소번호']==646 ]['이용거리'].fillna(789.789, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10692\3090146903.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df[ df['대여소번호']==646 ]['이용거리'].fillna(789.789, inplace=True)
# 0     1100.000
# 1     1420.000
# 2      789.789
# 3     1380.000
# 5     1350.000
# 6     1390.000
# 8     1160.000
# 9     1060.000
# ...

# %%
df[ df['대여소번호']==646 ]['이용거리']
# Out:
# 0     1100.0
# 1     1420.0
# 2        NaN
# 3     1380.0
# 5     1350.0
# 6     1390.0
# 8     1160.0
# 9     1060.0
# 10    1300.0
# 11    1060.0
# 12       NaN
# 13    1140.0
# 14    1220.0
# 15    1370.0
# 16    1350.0
# 17    1350.0
# 18    1130.0
# 19    1330.0
# 21    1310.0
# 22    1380.0
# 24    1070.0
# Name: 이용거리, dtype: float64

# %%
df[ df['대여소번호']==646 ]['이용거리'] = df[ df['대여소번호']==646 ]['이용거리'].fillna(789.789)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10692\1804430024.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   df[ df['대여소번호']==646 ]['이용거리'] = df[ df['대여소번호']==646 ]['이용거리'].fillna(789.789)

# %%
df.loc[ df['대여소번호'] == 646, '이용거리' ] = df[ df['대여소번호']==646 ]['이용거리'].fillna(789.789)
df[ df['대여소번호']==646 ]['이용거리']
# Out:
# 0     1100.000
# 1     1420.000
# 2      789.789
# 3     1380.000
# 5     1350.000
# 6     1390.000
# 8     1160.000
# 9     1060.000
# 10    1300.000
# 11    1060.000
# 12     789.789
# 13    1140.000
# 14    1220.000
# 15    1370.000
# 16    1350.000
# 17    1350.000
# 18    1130.000
# 19    1330.000
# 21    1310.000
# 22    1380.000
# 24    1070.000
# Name: 이용거리, dtype: float64
