# %% [markdown]
# # Pandas
# - 특정 데이터를 DataFrame 형식으로 처리

# %%
import pandas as pd

# %%
df = pd.read_csv("../data_set/1.pandas/1.pandas.csv")
df
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df['name']
# Out:
# 0     Kim
# 1     Cho
# 2    Choi
# 3      jo
# Name: name, dtype: str

# %%
df.age
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# Name: age, dtype: int64

# %%
df[["name", "age"]]
# Out:
#    name  age
# 0   Kim   20
# 1   Cho   30
# 2  Choi   40
# 3    jo   50

# %%
df[["name"]]
# Out:
#    name
# 0   Kim
# 1   Cho
# 2  Choi
# 3    jo

# %%
df
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df[1:3]
# Out:
#    name  score grade  age
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40

# %%
df.loc[1:3]
# Out:
#    name  score grade  age
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df[1:3]['name'] # 복사본
# Out:
# 1     Cho
# 2    Choi
# Name: name, dtype: str

# %%
df.loc[1:3, 'name'] # 원본
# Out:
# 1     Cho
# 2    Choi
# 3      jo
# Name: name, dtype: str

# %%
df[1:3]['name'] = "aaaa"
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17972\1910646238.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   df[1:3]['name'] = "aaaa"

# %%
df
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df.loc[1:3, 'name'] = 'aaaa'

# %%
df
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1  aaaa   95.0     A   30
# 2  aaaa   90.5     B   40
# 3  aaaa   85.7     B   50

# %%
df = pd.read_csv("../data_set/1.pandas/1.pandas.csv")
df
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df.loc[ : , 'name']
# Out:
# 0     Kim
# 1     Cho
# 2    Choi
# 3      jo
# Name: name, dtype: str

# %%
df.loc[:, ['name', 'age']]
# Out:
#    name  age
# 0   Kim   20
# 1   Cho   30
# 2  Choi   40
# 3    jo   50

# %%
df.loc[:]
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df['grade'] == 'A'
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: grade, dtype: bool

# %%
df.loc[ df['grade'] == 'A']
# Out:
#   name  score grade  age
# 0  Kim  100.0     A   20
# 1  Cho   95.0     A   30

# %%
df.loc[ df['grade'] == 'A', 'grade'] = 'CCC'
df
# Out:
#    name  score grade  age
# 0   Kim  100.0   CCC   20
# 1   Cho   95.0   CCC   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df.drop(2) # index 기준으로 drop
# Out:
#   name  score grade  age
# 0  Kim  100.0   CCC   20
# 1  Cho   95.0   CCC   30
# 3   jo   85.7     B   50

# %%
df
# Out:
#    name  score grade  age
# 0   Kim  100.0   CCC   20
# 1   Cho   95.0   CCC   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df = df.drop(2)
df
# Out:
#   name  score grade  age
# 0  Kim  100.0   CCC   20
# 1  Cho   95.0   CCC   30
# 3   jo   85.7     B   50

# %%
df.drop(1, inplace = True) # 자기 자신에 적용
df
# Out:
#   name  score grade  age
# 0  Kim  100.0   CCC   20
# 3   jo   85.7     B   50

# %%
df.drop(0, axis=0, inplace=True) # 행
df
# Out:
#   name  score grade  age
# 3   jo   85.7     B   50

# %%
df.drop('name', axis=1, inplace=True) # 열
df
# Out:
#    score grade  age
# 3   85.7     B   50

# %%
df = pd.read_csv("../data_set/1.pandas/1.pandas.csv")
df
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df['score'] < 95
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: score, dtype: bool

# %%
df[ df['score'] < 95 ]
# Out:
#    name  score grade  age
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df.loc[ df['score'] < 95 ]
# Out:
#    name  score grade  age
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df[ df['score'] < 95 ]['name']
# Out:
# 2    Choi
# 3      jo
# Name: name, dtype: str

# %%
df[ df['score'] < 95][ ['name', 'age'] ]
# Out:
#    name  age
# 2  Choi   40
# 3    jo   50

# %%
df.loc[ df['score'] < 95, ['name', 'age'] ]
# Out:
#    name  age
# 2  Choi   40
# 3    jo   50

# %%
df.columns
# Out:
# Index(['name', 'score', 'grade', 'age'], dtype='str')

# %%
df.values
# Out:
# array([['Kim', 100.0, 'A', 20],
#        ['Cho', 95.0, 'A', 30],
#        ['Choi', 90.5, 'B', 40],
#        ['jo', 85.7, 'B', 50]], dtype=object)

# %%
df.dtypes
# Out:
# name         str
# score    float64
# grade        str
# age        int64
# dtype: object

# %%
df['grade']
# Out:
# 0    A
# 1    A
# 2    B
# 3    B
# Name: grade, dtype: str

# %%
df['grade'].isin(['A'])
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: grade, dtype: bool

# %%
df[ df['grade'].isin(['A']) ]
# Out:
#   name  score grade  age
# 0  Kim  100.0     A   20
# 1  Cho   95.0     A   30

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
index_name = ['김', '이', '박', '조']
df.index = index_name
df
# Out:
#    name  score grade  age
# 김   Kim  100.0     A   20
# 이   Cho   95.0     A   30
# 박  Choi   90.5     B   40
# 조    jo   85.7     B   50

# %%
df.index
# Out:
# Index(['김', '이', '박', '조'], dtype='str')

# %%
df[1:3]
# Out:
#    name  score grade  age
# 이   Cho   95.0     A   30
# 박  Choi   90.5     B   40

# %%
df['이':'조']
# Out:
#    name  score grade  age
# 이   Cho   95.0     A   30
# 박  Choi   90.5     B   40
# 조    jo   85.7     B   50
